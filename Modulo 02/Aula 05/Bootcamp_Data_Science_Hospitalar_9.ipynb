# %% [markdown]
# Caderno de exploracao dos dados do datasus 2008 pra frente

# %%
import pandas as pd

# %%
dados = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv",
                    encoding="ISO-8859-1", 
                    skiprows = 3, sep=";", skipfooter=12,
                    thousands=".", decimal=",")
dados.head()
# Out:
# <ipython-input-2-4f23a5396325>:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/agendamento-hospitalar/main/dados/A160324189_28_143_208.csv",
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan     2020/Fev  \
# 0        -        -        -  ...   8660753.05   8326416.32   8413784.42
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan  \
# 22        -        -        -        -  ...  88720873.59  97474362.62
# 23        -        -        -        -  ...  17844511.04  18653296.92
# 24        -        -        -        -  ...  13827706.20  15445693.74
# 25        -        -        -        -  ...  34050298.55  36312121.02
# 26        -        -        -        -  ...  19207148.01  20429067.27
#
#        2020/Fev     2020/Mar     2020/Abr     2020/Mai     2020/Jun  \
# ...

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42487939.51
# 19   179898070.22
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21041071.33
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26636409.892222222

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago")
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %% [markdown]
# # Desafio: escolher um título mais descritivo, que passe a  mensagem adequada.

# %% [markdown]
# # Desafio: faça a mesma análise pro mês mais recente.

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2019/Nov  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  8948605.66
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3174249.43
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 14781332.42
# 3   808448.39   771687.83   876091.18   896952.53  ...  3121104.71
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 35555518.00
#
#      2019/Dez    2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai  \
# ...

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 25 Paraíba               97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Abr     2472063.08
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# Total      420668039.63
# Name: 12 Acre, Length: 157, dtype: float64

# %%
usaveis.plot(figsize=(12,6))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
usaveis.T.tail()
# Out:
# Unidade da Federação  11 Rondônia      12 Acre   13 Amazonas   14 Roraima  \
# 2020/Abr               7423678.64   2472063.08   16330913.81   2304961.42
# 2020/Mai               8581195.13   2383895.48   19441150.53   2910776.44
# 2020/Jun               9193593.76   2199920.70   17509334.66   3216466.51
# 2020/Jul               7407388.24   1163813.08   13358514.02   2739498.41
# Total                929129659.72 420668039.63 1771654871.23 305010883.18
#
# Unidade da Federação       15 Pará     16 Amapá  17 Tocantins   21 Maranhão  \
# 2020/Abr               28714969.96   1774558.12    6204453.42   23938156.77
# 2020/Mai               41248502.78   2701014.87    6732370.56   32979447.97
# 2020/Jun               35396030.78   2699492.23    5018138.13   31128144.66
# 2020/Jul               27618727.51   2155083.37    4489665.87   24374205.15
# Total                4437115730.71 291637984.75  999998621.85 3632860959.84
#
# ...

# %%
usaveis.T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis.T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Desafio: reposicionar a legenda. Dentro? Fora? Onde?

# %% [markdown]
# # Desafio: mudar palete de cores com o matplotlib

# %%
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %%
usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
usaveis[:5]
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis[:7].T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 32 Espírito Santo       57408.11  284224.80  1152115.25  2296383.23
# 31 Minas Gerais        971394.37 2861781.50 10018011.35 21730281.63
# 24 Rio Grande do Norte 134605.36  272088.08   684678.30  1695824.89
# 17 Tocantins             4113.76   76633.06   343702.61  1068685.94
# 53 Distrito Federal    191951.47  769966.25  2165619.56  3813256.48
# 50 Mato Grosso do Sul  199556.12  573675.41  1069816.66  1995899.52
# 16 Amapá                33672.74  104822.98   118378.28   226661.18
#
#                           2007/Dez     2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 32 Espírito Santo       5724199.54  16212109.41 10032886.43 12262049.08
# 31 Minas Gerais        43429517.54 205912743.65 70301089.50 79119005.51
# 24 Rio Grande do Norte  4730811.68  11763899.23  9110108.87 10126626.54
# 17 Tocantins            3022200.87   5136474.61  5051932.07  5200151.87
# ...

# %%
usaveis.sample(7)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 42 Santa Catarina     693955.05 1092964.12  3562300.82  7578502.38
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 21 Maranhão           385330.18 1018352.93  2277717.78  4334468.23
# 52 Goiás              179395.82  418053.58  1198730.25  2712117.54
# 32 Espírito Santo      57408.11  284224.80  1152115.25  2296383.23
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 42 Santa Catarina    14772555.10   53034384.67  24409572.92  27483480.50
# 33 Rio de Janeiro    13627123.27  250564959.99  44122593.19  42892665.52
# 31 Minas Gerais      43429517.54  205912743.65  70301089.50  79119005.51
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# ...

# %%
# ideia de como funciona aleatoriedade
# pseudo randomness

# seed = 6987
# random = seed / 10, seed = seed * 2 /3


# random ===> 698...... (seed=4658)
# random ==> 465 (seed = 310)
# random ==> 31

# %% [markdown]
# # Desafio: adicionar uma coluna mostrando a região de cada estado

# %%
usaveis["Total"] = usaveis.sum(axis=1) # [0,1,2] ["SP"]
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
ordenado_por_total.index = ordenado_por_total.index.str[3:]
ordenado_por_total = ordenado_por_total.drop("Total", axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# São Paulo            1665349.90 4434168.64 14577395.84 35032259.98
# Minas Gerais          971394.37 2861781.50 10018011.35 21730281.63
# Paraná                554800.22 1431708.01  4630402.44 11120030.79
# Rio Grande do Sul    1049252.33 3182913.14  8571312.11 16592432.80
# Rio de Janeiro        469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# São Paulo            76668547.41 1023564534.21 172834914.73 170481849.56
# Minas Gerais         43429517.54  205912743.65  70301089.50  79119005.51
# Paraná               28790722.87   58081334.45  48855046.46  55611791.07
# Rio Grande do Sul    30134255.70   51064610.03  45897704.82  52928695.92
# Rio de Janeiro       13627123.27  250564959.99  44122593.19  42892665.52
#
# ...

# %% [markdown]
# # Desafio: deixar o gráfico mais bonito. A mensagem mais clara.

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# #Desafio: adicione seu estado aos 5 estados existentes e plote

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Desafio: googlar os casos de dengue no Brasil e se reflete nos gastos

# %% [markdown]
# #Desafio: plotar só os estados do sudeste e ver se afetou com um pico em 2012/2013 de forma similar esses estados

# %% [markdown]
# #Desafio: adicionar seu estado escolhido novamente e deixe o gráfico informativo com suas informações claras

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(10,6))
plt.ylim(100, 350)
# Out:
# (100.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-24:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-36:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-60:]].head(3).T.plot(figsize=(10,6))
plt.ylim(0, 350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total.head(5).T.plot(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total.head(5).T.plot(figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total.head(5).T.plot(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           282.71
# Minas Gerais        120.47
# Paraná               80.32
# Rio Grande do Sul    78.93
# Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente.plot()
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_do_mais_recente.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='2020/Jul'>

# %% [markdown]
# Horrores da pizza atual:
#
# - legenda está horrível
# - número de fatias inacreditável
#
# Já estamos com uma vantagem:
# - o gráfico veio ordenado

# %%
gastos_do_mais_recente.sample(frac=1).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='2020/Jul'>

# %% [markdown]
# Horrores da pizza atual:
#
# - legenda está horrível
# - número de fatias inacreditável
# - não dá para saber a ordem
# - cores repetidas
# - muito ruim para definir ordem
# - péssimo para COMPARAR

# %%
# visualização simples pra valor absoluto

gastos_do_mais_recente
# Out:
# Unidade da Federação
# São Paulo             282.71
# Minas Gerais          120.47
# Paraná                 80.32
# Rio Grande do Sul      78.93
# Rio de Janeiro         71.54
# Bahia                  58.90
# Pernambuco             62.33
# Santa Catarina         51.76
# Ceará                  30.81
# Goiás                  33.50
# Pará                   27.62
# Maranhão               24.37
# Espírito Santo         27.46
# Rio Grande do Norte    19.59
# Paraíba                15.49
# Distrito Federal       22.23
# Mato Grosso do Sul     12.51
# Piauí                  18.02
# Alagoas                13.09
# Mato Grosso            13.08
# Amazonas               13.36
# Sergipe                 3.31
# Tocantins               4.49
# Rondônia                7.41
# Acre                    1.16
# Roraima                 2.74
# Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["Rio de Janeiro"]
# Out:
# Unidade da Federação
# São Paulo             3.95
# Minas Gerais          1.68
# Paraná                1.12
# Rio Grande do Sul     1.10
# Rio de Janeiro        1.00
# Bahia                 0.82
# Pernambuco            0.87
# Santa Catarina        0.72
# Ceará                 0.43
# Goiás                 0.47
# Pará                  0.39
# Maranhão              0.34
# Espírito Santo        0.38
# Rio Grande do Norte   0.27
# Paraíba               0.22
# Distrito Federal      0.31
# Mato Grosso do Sul    0.17
# Piauí                 0.25
# Alagoas               0.18
# Mato Grosso           0.18
# Amazonas              0.19
# Sergipe               0.05
# Tocantins             0.06
# Rondônia              0.10
# Acre                  0.02
# Roraima               0.04
# Amapá                 0.03
# Name: 2020/Jul, dtype: float64

# %% [markdown]
# # Criar a tabela de comparação com o seu estado (ou estado de preferência)

# %%
(gastos_do_mais_recente / gastos_do_mais_recente.loc["Rio de Janeiro"]).head(5)
# Out:
# Unidade da Federação
# São Paulo           3.95
# Minas Gerais        1.68
# Paraná              1.12
# Rio Grande do Sul   1.10
# Rio de Janeiro      1.00
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %% [markdown]
# # Desafio: documentação do matplotlib e pandas para colocar grid no gráfico

# %% [markdown]
# # Desafio: gráfico de barra do gasto dos outros estados em função ao seu estado

# %% [markdown]
# # Desafio: gasto por população de dois estados. escolha dois estados. gráfico de barras.

# %% [markdown]
# # Desafio: Explore e levante hipóteses e perguntas.

# %% [markdown]
# # Super desafio: Escolha outro valor fora Valor Aprovado no TABNET e explore.

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
gastos_proporcionais = gastos_do_mais_recente / gastos_do_mais_recente.sum()
gastos_proporcionais.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
ibge_estimativa = pd.read_excel("https://github.com/alura-cursos/agendamento-hospitalar/raw/main/dados/estimativa_dou_2020.xls")
ibge_estimativa.head()
# Out:
#   ESTIMATIVAS DA POPULAÇÃO RESIDENTE NO BRASIL E UNIDADES DA FEDERAÇÃO COM DATA DE REFERÊNCIA EM 1º DE JULHO DE 2020  \
# 0                     BRASIL E UNIDADES DA FEDERAÇÃO
# 1                                             Brasil
# 2                                       Região Norte
# 3                                           Rondônia
# 4                                               Acre
#
#    Unnamed: 1          Unnamed: 2
# 0         nan  POPULAÇÃO ESTIMADA
# 1         nan           211755692
# 2         nan            18672591
# 3         nan             1796460
# 4         nan              894470

# %%
dados_da_populacao = """Posição	Unidade federativa	População	% da pop. total	País comparável
(habitantes)

1	 São Paulo	46 289 333	21,9%	Flag of Spain.svg Espanha (46 439 864)
2	 Minas Gerais	21 292 666	10,1%	 Sri Lanka (20 675 000)
3	 Rio de Janeiro	17 366 189	8,2%	 Países Baixos (16 922 900)
4	Bahia Bahia	14 930 634	7,1%	 Chade (14 037 000)
5	 Paraná	11 516 840	5,4%	 Bolívia (11 410 651)
6	 Rio Grande do Sul	11 422 973	5,4%	 Bélgica (11 250 659)
7	 Pernambuco	9 616 621	4,5%	 Bielorrússia (9 485 300)
8	 Ceará	9 187 103	4,3%	 Emirados Árabes Unidos (9 157 000)
9	Pará Pará	8 690 745	4,1%	 Áustria (8 602 112)
10	 Santa Catarina	7 252 502	3,4%	 Sérvia (7 114 393)
11	 Maranhão	7 114 598	3,4%	 Paraguai (7 003 406)
12	 Goiás	7 113 540	3,4%	 Paraguai (7 003 406)
13	 Amazonas	4 207 714	2,0%	 Líbano (4 168 000)
14	 Espírito Santo	4 064 052	1,9%	 Líbano (4 168 000)
15	 Paraíba	4 039 277	1,9%	 Líbano (4 168 000)
16	 Rio Grande do Norte	3 534 165	1,7%	 Uruguai (3 415 866)
17	 Mato Grosso	3 526 220	1,7%	 Uruguai (3 415 866)
18	 Alagoas	3 351 543	1,6%	 Uruguai (3 415 866)
19	 Piauí	3 281 480	1,6%	 Kuwait (3 268 431)
20	 Distrito Federal	3 055 149	1,4%	 Lituânia (2 900 787)
21	 Mato Grosso do Sul	2 809 394	1,3%	 Jamaica (2 717 991)
22	 Sergipe	2 318 822	1,1%	 Namíbia (2 280 700)
23	 Rondônia	1 796 460	0,8%	 Gabão (1 725 000)
24	 Tocantins	1 590 248	0,7%	 Bahrein (1 359 800)
25	 Acre	894 470	0,4%	 Fiji (859 178)
26	 Amapá	861 773	0,4%	 Fiji (859 178)
27	 Roraima	631 181	0,3%	 Luxemburgo (562 958)"""

# fonte: https://pt.wikipedia.org/wiki/Lista_de_unidades_federativas_do_Brasil_por_popula%C3%A7%C3%A3o#cite_note-IBGE_POP-1

# %% [markdown]
# # Estruturar uma função para a leitura e limpeza dessa tabela, devolvendo a tabela populacao e a tabela unida

# %%
from io import StringIO

dados_da_populacao_io = StringIO(dados_da_populacao)

populacao = pd.read_csv(dados_da_populacao_io, sep="\t")
populacao = populacao.dropna()
populacao["populacao"] = populacao["População"].str.replace(" ", "").astype(int)
populacao["uf"] = populacao["Unidade federativa"]
populacao = populacao[["populacao", "uf"]].set_index("uf")
display(populacao.head())
display(populacao.info())
# Out:
#                  populacao
# uf
#  São Paulo        46289333
#  Minas Gerais     21292666
#  Rio de Janeiro   17366189
# Bahia Bahia       14930634
#  Paraná           11516840
# <class 'pandas.core.frame.DataFrame'>
# Index: 27 entries,  São Paulo to  Roraima
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   populacao  27 non-null     int32
# dtypes: int32(1)
# memory usage: 324.0+ bytes
# None

# %%
populacao.index.str[:3]
# Out:
# Index([' Sã', ' Mi', ' Ri', 'Bah', ' Pa', ' Ri', ' Pe', ' Ce', 'Par', ' Sa',
#        ' Ma', ' Go', ' Am', ' Es', ' Pa', ' Ri', ' Ma', ' Al', ' Pi', ' Di',
#        ' Ma', ' Se', ' Ro', ' To', ' Ac', ' Am', ' Ro'],
#       dtype='object', name='uf')

# %% [markdown]
# # Desafio: ler esse arquivo direto do wikipedia (html).

# %%
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# São Paulo           282.71
# Minas Gerais        120.47
# Paraná               80.32
# Rio Grande do Sul    78.93
# Rio de Janeiro       71.54
# Name: 2020/Jul, dtype: float64

# %% [markdown]
# # Desafio: explorar mais métodos de String do python e str do pandas

# %%
populacao.index = populacao.index.str.strip()
populacao.head()
# Out:
#                 populacao
# uf
# São Paulo        46289333
# Minas Gerais     21292666
# Rio de Janeiro   17366189
# Bahia Bahia      14930634
# Paraná           11516840

# %%
populacao.index[0].strip()
# Out:
# 'São Paulo'

# %%
for estado in gastos_do_mais_recente.index:
  # print(f"{estado} {estado} => {estado}")
  populacao.index = populacao.index.str.replace(f"{estado} {estado}", estado)
populacao.index
# Out:
# Index(['São Paulo', 'Minas Gerais', 'Rio de Janeiro', 'Bahia', 'Paraná',
#        'Rio Grande do Sul', 'Pernambuco', 'Ceará', 'Pará', 'Santa Catarina',
#        'Maranhão', 'Goiás', 'Amazonas', 'Espírito Santo', 'Paraíba',
#        'Rio Grande do Norte', 'Mato Grosso', 'Alagoas', 'Piauí',
#        'Distrito Federal', 'Mato Grosso do Sul', 'Sergipe', 'Rondônia',
#        'Tocantins', 'Acre', 'Amapá', 'Roraima'],
#       dtype='object', name='uf')

# %%
gastos_e_populacao_recente = populacao.join(gastos_do_mais_recente)
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul
# uf
# São Paulo        46289333    282.71
# Minas Gerais     21292666    120.47
# Rio de Janeiro   17366189     71.54
# Bahia            14930634     58.90
# Paraná           11516840     80.32

# %%
def insere_gastos_e_gasto_por_habitante_para(todos_os_gastos: pd.DataFrame, dados: pd.DataFrame, mes: str):
  gastos_do_mes = todos_os_gastos[mes]
  dados[f"gastos_{mes}"] = gastos_do_mes * 1000000
  dados[f"gasto_por_habitante_{mes}"] = dados[f"gastos_{mes}"] / dados["populacao"]

# %%
ordenado_por_total["2020/Jul"]
# Out:
# Unidade da Federação
# São Paulo             282.71
# Minas Gerais          120.47
# Paraná                 80.32
# Rio Grande do Sul      78.93
# Rio de Janeiro         71.54
# Bahia                  58.90
# Pernambuco             62.33
# Santa Catarina         51.76
# Ceará                  30.81
# Goiás                  33.50
# Pará                   27.62
# Maranhão               24.37
# Espírito Santo         27.46
# Rio Grande do Norte    19.59
# Paraíba                15.49
# Distrito Federal       22.23
# Mato Grosso do Sul     12.51
# Piauí                  18.02
# Alagoas                13.09
# Mato Grosso            13.08
# Amazonas               13.36
# Sergipe                 3.31
# Tocantins               4.49
# Rondônia                7.41
# Acre                    1.16
# Roraima                 2.74
# Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
ordenado_por_total["2020/Jul"]
# Out:
# Unidade da Federação
# São Paulo             282.71
# Minas Gerais          120.47
# Paraná                 80.32
# Rio Grande do Sul      78.93
# Rio de Janeiro         71.54
# Bahia                  58.90
# Pernambuco             62.33
# Santa Catarina         51.76
# Ceará                  30.81
# Goiás                  33.50
# Pará                   27.62
# Maranhão               24.37
# Espírito Santo         27.46
# Rio Grande do Norte    19.59
# Paraíba                15.49
# Distrito Federal       22.23
# Mato Grosso do Sul     12.51
# Piauí                  18.02
# Alagoas                13.09
# Mato Grosso            13.08
# Amazonas               13.36
# Sergipe                 3.31
# Tocantins               4.49
# Rondônia                7.41
# Acre                    1.16
# Roraima                 2.74
# Amapá                   2.16
# Name: 2020/Jul, dtype: float64

# %%
# horripilante (data visualization)
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Jul")
gastos_e_populacao_recente[["gastos_2020/Jul", "populacao"]].plot()
# Out:
# <AxesSubplot:xlabel='uf'>

# %%
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul  gastos_2020/Jul  \
# uf
# São Paulo        46289333    282.71     282709570.31
# Minas Gerais     21292666    120.47     120467187.34
# Rio de Janeiro   17366189     71.54      71540227.33
# Bahia            14930634     58.90      58898100.40
# Paraná           11516840     80.32      80320852.69
#
#                 gasto_por_habitante_2020/Jul
# uf
# São Paulo                               6.11
# Minas Gerais                            5.66
# Rio de Janeiro                          4.12
# Bahia                                   3.94
# Paraná                                  6.97

# %%
gastos_e_populacao_recente.loc[["Rio Grande do Sul", "São Paulo"]]
# Out:
#                    populacao  2020/Jul  gastos_2020/Jul  \
# uf
# Rio Grande do Sul   11422973     78.93      78929703.81
# São Paulo           46289333    282.71     282709570.31
#
#                    gasto_por_habitante_2020/Jul
# uf
# Rio Grande do Sul                          6.91
# São Paulo                                  6.11

# %%
78929703.81/11422973
# Out:
# 6.909733902899009

# %%
282709570.31/46289333
# Out:
# 6.107445322446102

# %%
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul  gastos_2020/Jul  \
# uf
# São Paulo        46289333    282.71     282709570.31
# Minas Gerais     21292666    120.47     120467187.34
# Rio de Janeiro   17366189     71.54      71540227.33
# Bahia            14930634     58.90      58898100.40
# Paraná           11516840     80.32      80320852.69
#
#                 gasto_por_habitante_2020/Jul
# uf
# São Paulo                               6.11
# Minas Gerais                            5.66
# Rio de Janeiro                          4.12
# Bahia                                   3.94
# Paraná                                  6.97

# %%
gastos_e_populacao_recente["gasto_por_habitante_2020/Jul"].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='uf'>

# %% [markdown]
# # Desafio: ordenar por gasto por habitante. Ordenar por habitantes

# %%
import seaborn as sns

sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2020/Jul")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gastos_2020/Jul'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2020/Jul")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gastos_2020/Jul'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2020/Jul")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gasto_por_habitante_2020/Jul'>

# %% [markdown]
# # Desafio: fazer os últimos gráficos para o mês anterior a este

# %% [markdown]
# # Desafio: fazer os últimos gráficos com os dois no mesmo gráfico

# %%
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Jun")
insere_gastos_e_gasto_por_habitante_para(ordenado_por_total, gastos_e_populacao_recente, "2020/Mai")
gastos_e_populacao_recente.head()
# Out:
#                 populacao  2020/Jul  gastos_2020/Jul  \
# uf
# São Paulo        46289333    282.71     282709570.31
# Minas Gerais     21292666    120.47     120467187.34
# Rio de Janeiro   17366189     71.54      71540227.33
# Bahia            14930634     58.90      58898100.40
# Paraná           11516840     80.32      80320852.69
#
#                 gasto_por_habitante_2020/Jul  gastos_2020/Jun  \
# uf
# São Paulo                               6.11     299060851.62
# Minas Gerais                            5.66     135977571.87
# Rio de Janeiro                          4.12      77604925.21
# Bahia                                   3.94      65159300.63
# Paraná                                  6.97      92901461.36
#
#                 gasto_por_habitante_2020/Jun  gastos_2020/Mai  \
# uf
# São Paulo                               6.46     302857660.98
# Minas Gerais                            6.39     136867275.75
# Rio de Janeiro                          4.47      86281033.16
# ...

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2020/Jul")
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2020/Jun")
sns.scatterplot(data=gastos_e_populacao_recente / 1000000, x="populacao", y="gastos_2020/Mai")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gastos_2020/Jul'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2020/Jul")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gasto_por_habitante_2020/Jul'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2020/Jun")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gasto_por_habitante_2020/Jun'>

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=gastos_e_populacao_recente, x="populacao", y="gasto_por_habitante_2020/Mai")
# Out:
# <AxesSubplot:xlabel='populacao', ylabel='gasto_por_habitante_2020/Mai'>

# %% [markdown]
# # Desafio: Analise os gráficos e tente chegar a hipóteses que explicam o que você está entendendo dos dados. Lembre-se que a conclusão é uma hipótese. E que esses dados serão alterados.

# %%
ordenado_por_total.head()
# Out:
#                       2008/Fev  2008/Mar  2008/Abr  2008/Mai  2008/Jun  \
# Unidade da Federação
# São Paulo               172.83    170.48    170.28    172.40    175.42
# Minas Gerais             70.30     79.12     79.05     79.27     79.61
# Paraná                   48.86     55.61     56.12     55.57     56.09
# Rio Grande do Sul        45.90     52.93     51.97     51.68     53.76
# Rio de Janeiro           44.12     42.89     45.30     43.95     44.10
#
#                       2008/Jul  2008/Ago  2008/Set  2008/Out  2008/Nov  ...  \
# Unidade da Federação                                                    ...
# São Paulo               179.53    179.90    180.08    191.69    190.54  ...
# Minas Gerais             82.20     80.37     82.40     88.61     84.49  ...
# Paraná                   59.80     56.70     58.09     61.37     59.67  ...
# Rio Grande do Sul        56.39     56.23     57.91     59.59     57.57  ...
# ...

# %%
sns.scatterplot(x=ordenado_por_total.columns, y=ordenado_por_total.loc["São Paulo"])
# Out:
# <AxesSubplot:ylabel='São Paulo'>

# %%
mensal = ordenado_por_total.T
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  Rio Grande do Sul  \
# 2008/Fev                 172.83         70.30   48.86              45.90
# 2008/Mar                 170.48         79.12   55.61              52.93
# 2008/Abr                 170.28         79.05   56.12              51.97
# 2008/Mai                 172.40         79.27   55.57              51.68
# 2008/Jun                 175.42         79.61   56.09              53.76
#
# Unidade da Federação  Rio de Janeiro  Bahia  Pernambuco  Santa Catarina  \
# 2008/Fev                       44.12  33.41       26.22           24.41
# 2008/Mar                       42.89  41.30       30.72           27.48
# 2008/Abr                       45.30  42.83       30.59           27.81
# 2008/Mai                       43.95  42.07       31.41           28.35
# 2008/Jun                       44.10  39.91       28.95           28.99
#
# Unidade da Federação  Ceará  Goiás  ...  Piauí  Alagoas  Mato Grosso  \
# ...

# %% [markdown]
# # Desafio: use seu estado

# %%
sns.scatterplot(data=mensal, x=mensal.index, y="São Paulo")
# Out:
# <AxesSubplot:ylabel='São Paulo'>

# %% [markdown]
# # Desafio: Formatar o eixo y StrMethodFormatter, colocar um título e colocar título nos 2 eixos. E alterar fonte (tamanho) dos títulos.

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal, x=mensal.index, y="São Paulo")
plt.xticks(rotation=30)
plt.ylim(0, 350)
ax.xaxis.set_major_locator(ticker.IndexLocator(base=12, offset=11))
plt.grid(linestyle="--")
plt.show()

# %%
from datetime import date

meses = {
    "Jan" : 1,
    "Fev" : 2,
    "Mar" : 3,
    "Abr" : 4,
    "Mai" : 5,
    "Jun" : 6,
    "Jul" : 7,
    "Ago" : 8,
    "Set" : 9,
    "Out" : 10,
    "Nov" : 11,
    "Dez" : 12
}

def para_dia(ano_mes: str):
  ano: int = int(ano_mes[:4])
  mes: str = ano_mes[5:]
  mes_numero: int = meses[mes]
  return date(ano, mes_numero, 1)

mensal.index = mensal.index.map(para_dia)
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  Rio Grande do Sul  \
# 2008-02-01               172.83         70.30   48.86              45.90
# 2008-03-01               170.48         79.12   55.61              52.93
# 2008-04-01               170.28         79.05   56.12              51.97
# 2008-05-01               172.40         79.27   55.57              51.68
# 2008-06-01               175.42         79.61   56.09              53.76
#
# Unidade da Federação  Rio de Janeiro  Bahia  Pernambuco  Santa Catarina  \
# 2008-02-01                     44.12  33.41       26.22           24.41
# 2008-03-01                     42.89  41.30       30.72           27.48
# 2008-04-01                     45.30  42.83       30.59           27.81
# 2008-05-01                     43.95  42.07       31.41           28.35
# 2008-06-01                     44.10  39.91       28.95           28.99
#
# Unidade da Federação  Ceará  Goiás  ...  Piauí  Alagoas  Mato Grosso  \
# ...

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal, x=mensal.index, y="São Paulo")
plt.xticks(rotation=30)
plt.ylim(0, 350)
plt.grid(linestyle="--")
plt.show()

# %%
mensal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 2008-02-01 to 2020-07-01
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   São Paulo            150 non-null    float64
#  1   Minas Gerais         150 non-null    float64
#  2   Paraná               150 non-null    float64
#  3   Rio Grande do Sul    150 non-null    float64
#  4   Rio de Janeiro       150 non-null    float64
#  5   Bahia                150 non-null    float64
#  6   Pernambuco           150 non-null    float64
#  7   Santa Catarina       150 non-null    float64
#  8   Ceará                150 non-null    float64
#  9   Goiás                150 non-null    float64
#  10  Pará                 150 non-null    float64
#  11  Maranhão             150 non-null    float64
#  12  Espírito Santo       150 non-null    float64
#  13  Rio Grande do Norte  150 non-null    float64
# ...

# %%
mensal.index[0]
# Out:
# datetime.date(2008, 2, 1)

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal, x=mensal.index, y="São Paulo")
ax = sns.lineplot(data=mensal, x=mensal.index, y="Minas Gerais")
plt.xticks(rotation=30)
plt.ylim(0, 350)
plt.grid(linestyle="--")
plt.show()

# problemas:
# 1. eixos
# 2. legenda
# 3. serio mesmo? copy e paste das linhas do grafico?

# %%
mensal.head()
# Out:
# Unidade da Federação  São Paulo  Minas Gerais  Paraná  Rio Grande do Sul  \
# 2008-02-01               172.83         70.30   48.86              45.90
# 2008-03-01               170.48         79.12   55.61              52.93
# 2008-04-01               170.28         79.05   56.12              51.97
# 2008-05-01               172.40         79.27   55.57              51.68
# 2008-06-01               175.42         79.61   56.09              53.76
#
# Unidade da Federação  Rio de Janeiro  Bahia  Pernambuco  Santa Catarina  \
# 2008-02-01                     44.12  33.41       26.22           24.41
# 2008-03-01                     42.89  41.30       30.72           27.48
# 2008-04-01                     45.30  42.83       30.59           27.81
# 2008-05-01                     43.95  42.07       31.41           28.35
# 2008-06-01                     44.10  39.91       28.95           28.99
#
# Unidade da Federação  Ceará  Goiás  ...  Piauí  Alagoas  Mato Grosso  \
# ...

# %% [markdown]
# ```
# MES        VALOR     ESTADO
# 2008-03    170.48    Sao Paulo
# 2008-03     79.12    Minas Gerais
# ...
# ```

# %%
mensal_aberto = mensal.reset_index().melt(id_vars=["index"], value_vars=mensal.columns)
mensal_aberto.columns = ["dia_mes_ano", "uf", "gasto"]
mensal_aberto['dia_mes_ano'] = mensal_aberto['dia_mes_ano'].astype('datetime64')
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto
# 0  2008-02-01  São Paulo 172.83
# 1  2008-03-01  São Paulo 170.48
# 2  2008-04-01  São Paulo 170.28
# 3  2008-05-01  São Paulo 172.40
# 4  2008-06-01  São Paulo 175.42

# %% [markdown]
# # Desafio: voltar atrás... partindo do `mensal_aberto` chegar no `mensal`

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto, x="dia_mes_ano", y="gasto", hue="uf")
plt.xticks(rotation=30)
plt.ylim(0, 350)
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# # Desafio: melhorar o gráfico.
#
# - muitos estados, escolha os estados
# - palete de cores: https://seaborn.pydata.org/tutorial/color_palettes.html (27 cores?)
# - posição da legenda
# - titulo e titulo dos eixos

# %%
mensal_aberto["dia_mes_ano"][0]
# Out:
# Timestamp('2008-02-01 00:00:00')

# %%
mensal_aberto["dia_mes_ano"].head()
# Out:
# 0   2008-02-01
# 1   2008-03-01
# 2   2008-04-01
# 3   2008-05-01
# 4   2008-06-01
# Name: dia_mes_ano, dtype: datetime64[ns]

# %%
mensal_aberto["mes"] = mensal_aberto["dia_mes_ano"].dt.month
mensal_aberto["ano"] = mensal_aberto["dia_mes_ano"].dt.year
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano
# 0  2008-02-01  São Paulo 172.83    2  2008
# 1  2008-03-01  São Paulo 170.48    3  2008
# 2  2008-04-01  São Paulo 170.28    4  2008
# 3  2008-05-01  São Paulo 172.40    5  2008
# 4  2008-06-01  São Paulo 175.42    6  2008

# %%
mensal_aberto.query("uf=='São Paulo'")
# Out:
#     dia_mes_ano         uf  gasto  mes   ano
# 0    2008-02-01  São Paulo 172.83    2  2008
# 1    2008-03-01  São Paulo 170.48    3  2008
# 2    2008-04-01  São Paulo 170.28    4  2008
# 3    2008-05-01  São Paulo 172.40    5  2008
# 4    2008-06-01  São Paulo 175.42    6  2008
# ..          ...        ...    ...  ...   ...
# 145  2020-03-01  São Paulo 276.61    3  2020
# 146  2020-04-01  São Paulo 251.70    4  2020
# 147  2020-05-01  São Paulo 302.86    5  2020
# 148  2020-06-01  São Paulo 299.06    6  2020
# 149  2020-07-01  São Paulo 282.71    7  2020
#
# [150 rows x 5 columns]

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"), x="mes", y="gasto", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 350)
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# #Desafio: cores melhores (palete), títulos, ticks de mês com nome bonitinho (inglês? português?). Estado que você quiser estudar.

# %% [markdown]
# # Desafio: pegar dois estados de climas diferentes (estações de chuva diferente) e plotar as diversas linhas deles. Comparar picos etc. Gerar gráficos separados e conjuntos.

# %%
dias_por_mes = {
    1 : 31,
    2 : 28,
    3 : 31,
    4 : 30,
    5 : 31,
    6 : 30,
    7 : 31,
    8 : 31,
    9 : 30,
    10 : 31,
    11 : 30,
    12 : 31
}

# %%
mensal_aberto['gasto_diario'] = mensal_aberto['gasto'] / mensal_aberto['mes'].map(dias_por_mes)
mensal_aberto.head()
# Out:
#   dia_mes_ano         uf  gasto  mes   ano  gasto_diario
# 0  2008-02-01  São Paulo 172.83    2  2008          6.17
# 1  2008-03-01  São Paulo 170.48    3  2008          5.50
# 2  2008-04-01  São Paulo 170.28    4  2008          5.68
# 3  2008-05-01  São Paulo 172.40    5  2008          5.56
# 4  2008-06-01  São Paulo 175.42    6  2008          5.85

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='São Paulo'"), x="mes", y="gasto_diario", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 12)
plt.grid(linestyle="--")
plt.show()

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='Rio de Janeiro'"), x="mes", y="gasto_diario", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 12)
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# # Desafio 01: Melhorar o gráfico ano a ano:
#
# ## Mudar a palete de cor, colocar um título descritivo, adicionar ticks com o nome de cada mês no eixo x.

# %%
import locale
import calendar
locale.setlocale(locale.LC_TIME, 'pt_BR')
# Out:
# 'pt_BR'

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=mensal_aberto.query("uf=='Maranhão'"), x="mes", y="gasto_diario", hue="ano")
plt.xticks(rotation=30)
plt.ylim(0, 1.3)
ax.xaxis.set_major_formatter(lambda x, pos: calendar.month_name[pos])
ax.set_title("Gastos em sáude do SUS compativo entre anos do estado do Maranhão", fontsize=14, fontweight='bold')
plt.grid(linestyle="--")
plt.show()

# %% [markdown]
# ## Desafio 02: Pegar estados de climas diferentes (por exemplo, norte e sul) e plotar o gráfico de linhas, comparar ambos e compartilhar suas análises.

# %%
estados = ['Maranhão','Rio Grande do Sul']

estados_analise = mensal_aberto[mensal_aberto['uf'].isin(estados)]
estados_analise.head()
# Out:
#     dia_mes_ano                 uf  gasto  mes   ano  gasto_diario
# 450  2008-02-01  Rio Grande do Sul  45.90    2  2008          1.64
# 451  2008-03-01  Rio Grande do Sul  52.93    3  2008          1.71
# 452  2008-04-01  Rio Grande do Sul  51.97    4  2008          1.73
# 453  2008-05-01  Rio Grande do Sul  51.68    5  2008          1.67
# 454  2008-06-01  Rio Grande do Sul  53.76    6  2008          1.79

# %%
plt.figure(figsize=(10,6))
ax = sns.lineplot(data=estados_analise, x="dia_mes_ano", y="gasto_diario", hue="uf", palette="bright")
plt.xticks(rotation=30)
ax.set_title('Gastos de saúde do SUS entre estados Maranhão e Rio Grande do Sul', fontsize=14, fontweight='bold')

plt.xlabel('Anos')
plt.ylabel('Gastos por Milhão (R$)')
plt.legend(bbox_to_anchor=(1.27, 1))
plt.ylim(0, 4)
plt.grid(linestyle="--")

plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20,8), sharex=False, sharey=True) 

sns.lineplot(data=mensal_aberto.query("uf=='Maranhão'"), x="mes", y="gasto_diario", hue="ano", ax=ax[0])
sns.lineplot(data=mensal_aberto.query("uf=='Rio Grande do Sul'"), x="mes", y="gasto_diario", hue="ano", ax=ax[1])
fig.suptitle("Gastos em sáude do SUS compativo entre estados do Maranhão e Rio Grande do Sul", fontsize=14, fontweight='bold')

ax[0].xaxis.set_major_formatter(lambda x, pos: calendar.month_name[pos])
ax[1].xaxis.set_major_formatter(lambda x, pos: calendar.month_name[pos])
ax[0].set_title('Maranhão', fontsize=14)
ax[1].set_title('Rio Grande do Sul', fontsize=14)
ax[0].get_legend().remove()
ax[1].legend(bbox_to_anchor=(-0.52, 0.5, 0.5, 0.5), fontsize='large')
ax[0].set_ylabel('Gastos', fontsize=12)
ax[0].set_xlabel('Mês', fontsize=12)
ax[1].set_xlabel('Mês', fontsize=12)
ax[0].grid(linestyle="--")
ax[1].grid(linestyle="--")


plt.ylabel('Gastos')
plt.show()

# %% [markdown]
# ### Conclusão: No gráfico de linha acima em que estamos comparando os gastos diários com saúde do SUS entre os estados do Maranhão (Nordeste) e Rio Grande do Sul (Sul). Visualmente percebemos uma variação maior no estado do sul, enquanto no estado do nordeste, os gastos apresenta uma variança entre os meses mais estável. Posso supor, que isso ocorre devido a sazonalidade entre os estados.
